# %% [markdown]
# <a href="https://colab.research.google.com/github/mtarazona23/PROGCOM-B/blob/main/CLASE_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
#   File "/tmp/ipykernel_631/4275383071.py", line 1
#     1 = float(input("ingresa la Nota de estudiante 1"))
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
